# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(df['age'],kde=False)  # kde false kelyaver density plot yet nahi(area under the curve)
# Out:
# C:\Users\reliance\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age'>

# %%
sns.countplot(x='sex' , data=df , hue='survived')  # hue third part variable cha basis var split karto
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.barplot(x='sex' , y='fare' , data=df,palette='viridis')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.jointplot(x='age' , y = 'survived' , data=df , hue='sex')

# %%
sns.jointplot(x='age',y='fare',data=df)

# %%
sns.violinplot(x='sex' , y='age',data=df,hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>
